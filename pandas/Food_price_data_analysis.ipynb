# %%
import pandas as pd
fp = pd.read_excel('/Users/j.li/dev/data/SELECTED_FOOD_ADJUSTED_JAN2017_-_FEB_2019.xlsx', Sheet='NATIONAL')

# %%
fp
# Out:
#                                    Unnamed: 0           Unnamed: 1  \
# 0                                         NaN                  NaN
# 1                                  ItemLabels  2017-01-01 00:00:00
# 2                      Agric eggs medium size              459.977
# 3        Agric eggs(medium size price of one)              45.1071
# 4                      Beans brown,sold loose               471.22
# 5           Beans:white black eye. sold loose              420.764
# 6                                Beef Bone in              1107.67
# 7                               Beef,boneless               1378.4
# 8                           Bread sliced 500g              334.258
# 9                         Bread unsliced 500g              291.792
# 10                        Broken Rice (Ofada)                  472
# 11                               Chicken Feet               774.76
# 12                              Chicken Wings               1060.1
# ...

# %%
fp.tail(5)
# Out:
#                                    Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 41                             Plantain(ripe)     249.78      242.5
# 42                           Plantain(unripe)     203.38     193.79
# 43      Vegetable oil:1 bottle,specify bottle     388.39     370.77
# 44  Wheat flour: prepacked (golden penny 2kg)     645.92     648.33
# 45                                        NaN        NaN        NaN
#
#    Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 41     275.18     250.73     226.64     230.06     256.77     249.27
# 42     221.19     205.83        200     208.99     225.81     197.88
# 43     396.66     403.99     413.71     428.57     450.25     465.39
# 44        650     627.77     631.94     628.12     651.43     633.33
# 45        NaN        NaN        NaN        NaN        NaN        NaN
#
#    Unnamed: 9  ... Unnamed: 19 Unnamed: 20 Unnamed: 21 Unnamed: 22  \
# 41     251.15  ...     180.409     226.973     204.225         220
# ...

# %%
fp.dropna()
# Out:
#                                    Unnamed: 0           Unnamed: 1  \
# 1                                  ItemLabels  2017-01-01 00:00:00
# 2                      Agric eggs medium size              459.977
# 3        Agric eggs(medium size price of one)              45.1071
# 4                      Beans brown,sold loose               471.22
# 5           Beans:white black eye. sold loose              420.764
# 6                                Beef Bone in              1107.67
# 7                               Beef,boneless               1378.4
# 8                           Bread sliced 500g              334.258
# 9                         Bread unsliced 500g              291.792
# 10                        Broken Rice (Ofada)                  472
# 11                               Chicken Feet               774.76
# 12                              Chicken Wings               1060.1
# 13      Evaporated tinned milk carnation 170g               158.16
# ...

# %%
fp.shape
# Out:
# (46, 29)

# %%
fp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 29 columns):
# Unnamed: 0     44 non-null object
# Unnamed: 1     44 non-null object
# Unnamed: 2     44 non-null object
# Unnamed: 3     44 non-null object
# Unnamed: 4     44 non-null object
# Unnamed: 5     44 non-null object
# Unnamed: 6     44 non-null object
# Unnamed: 7     44 non-null object
# Unnamed: 8     44 non-null object
# Unnamed: 9     44 non-null object
# Unnamed: 10    44 non-null object
# Unnamed: 11    44 non-null object
# Unnamed: 12    44 non-null object
# Unnamed: 13    44 non-null object
# Unnamed: 14    44 non-null object
# Unnamed: 15    44 non-null object
# Unnamed: 16    44 non-null object
# Unnamed: 17    44 non-null object
# Unnamed: 18    44 non-null object
# Unnamed: 19    44 non-null object
# Unnamed: 20    44 non-null object
# Unnamed: 21    44 non-null object
# Unnamed: 22    44 non-null object
# Unnamed: 23    44 non-null object
# ...

# %%
fp.index
# Out:
# RangeIndex(start=0, stop=46, step=1)

# %%
fp.iloc[44]
# Out:
# Unnamed: 0     Wheat flour: prepacked (golden penny 2kg)
# Unnamed: 1                                        645.92
# Unnamed: 2                                        648.33
# Unnamed: 3                                           650
# Unnamed: 4                                        627.77
# Unnamed: 5                                        631.94
# Unnamed: 6                                        628.12
# Unnamed: 7                                        651.43
# Unnamed: 8                                        633.33
# Unnamed: 9                                         640.8
# Unnamed: 10                                       629.06
# Unnamed: 11                                          650
# Unnamed: 12                                      654.286
# Unnamed: 13                                      675.091
# Unnamed: 14                                          650
# Unnamed: 15                                      701.538
# ...

# %%
fp
# Out:
#                                    Unnamed: 0           Unnamed: 1  \
# 0                                         NaN                  NaN
# 1                                  ItemLabels  2017-01-01 00:00:00
# 2                      Agric eggs medium size              459.977
# 3        Agric eggs(medium size price of one)              45.1071
# 4                      Beans brown,sold loose               471.22
# 5           Beans:white black eye. sold loose              420.764
# 6                                Beef Bone in              1107.67
# 7                               Beef,boneless               1378.4
# 8                           Bread sliced 500g              334.258
# 9                         Bread unsliced 500g              291.792
# 10                        Broken Rice (Ofada)                  472
# 11                               Chicken Feet               774.76
# 12                              Chicken Wings               1060.1
# ...

# %%
fp.describe()
# Out:
#                     Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# count                       44       44.00   44.000000       44.00
# unique                      44       44.00   44.000000       44.00
# top     Catfish (obokun) fresh      894.65  447.741722      526.67
# freq                         1        1.00    1.000000        1.00
#
#         Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7   Unnamed: 8  \
# count    44.000000          44   44.000000       44.00    44.000000
# unique   44.000000          43   44.000000       44.00    44.000000
# top     379.383117         200  383.759398     1584.97  1407.559643
# freq      1.000000           2    1.000000        1.00     1.000000
#
#         Unnamed: 9  ...  Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22  \
# count        44.00  ...    44.000000    44.000000    44.000000         44.0
# unique       44.00  ...    44.000000    44.000000    44.000000         44.0
# ...

# %%
fp.keys
# Out:
# <bound method NDFrame.keys of                                    Unnamed: 0           Unnamed: 1  \
# 0                                         NaN                  NaN
# 1                                  ItemLabels  2017-01-01 00:00:00
# 2                      Agric eggs medium size              459.977
# 3        Agric eggs(medium size price of one)              45.1071
# 4                      Beans brown,sold loose               471.22
# 5           Beans:white black eye. sold loose              420.764
# 6                                Beef Bone in              1107.67
# 7                               Beef,boneless               1378.4
# 8                           Bread sliced 500g              334.258
# 9                         Bread unsliced 500g              291.792
# 10                        Broken Rice (Ofada)                  472
# 11                               Chicken Feet               774.76
# 12                              Chicken Wings               1060.1
# ...

# %%
fp['Agric eggs medium size']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/dev/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Agric eggs medium size'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-a2dc0025bca7> in <module>
# ...
